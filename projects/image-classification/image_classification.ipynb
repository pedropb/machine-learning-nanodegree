# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:19, 8.59MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np
from matplotlib import pyplot as plt

# Explore the dataset
for i in range(1,6):
    batch_id = i
    sample_id = 5
    plt.figure()
    helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile
#
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 3 Max Value: 219
# Image - Shape: (32, 32, 3)
# Label - Label Id: 3 Name: cat
#
# Stats of batch 3:
# Samples: 10000
# Label Counts: {0: 994, 1: 1042, 2: 965, 3: 997, 4: 990, 5: 1029, 6: 978, 7: 1015, 8: 961, 9: 1029}
# First 20 Labels: [8, 5, 0, 6, 9, 2, 8, 3, 6, 2, 7, 4, 6, 9, 0, 0, 7, 3, 7, 2]
#
# Example of Image 5:
# Image - Min Value: 9 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 2 Name: bird
#
# Stats of batch 4:
# Samples: 10000
# Label Counts: {0: 1003, 1: 963, 2: 1041, 3: 976, 4: 1004, 5: 1021, 6: 1004, 7: 981, 8: 1024, 9: 983}
# First 20 Labels: [0, 6, 0, 2, 7, 2, 1, 2, 4, 1, 5, 6, 6, 3, 1, 3, 5, 5, 8, 1]
#
# Example of Image 5:
# Image - Min Value: 13 Max Value: 169
# Image - Shape: (32, 32, 3)
# Label - Label Id: 2 Name: bird
#
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 5:
# Image - Min Value: 1 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 7 Name: horse

# %% [markdown]
# #### What are all possible labels?

# %%
print("All possible labels: ", helper._load_label_names())
# Out:
# All possible labels:  ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# #### What is the range of values for the image data?

# %%
def analyze_image_data(batch_id):
    features, labels = helper.load_cfar10_batch(cifar10_dataset_folder_path, batch_id)
    sample_id = np.random.randint(0, len(features))
    sample_image = features[sample_id]
    print("Sample image shape:", sample_image.shape)
    print("Features min %d, max %d" % (features.min(), features.max()))
    plt.figure()
    plt.axis('off')
    plt.title('Sample Image')
    plt.imshow(sample_image)
    colors = ['red', 'green', 'blue']
    for color in range(3):
        image = np.copy(sample_image)
        selector = [x for x in range(3) if x != color] 
        image[:,:,[selector]] = 0
        plt.figure()
        plt.axis('off')
        plt.title('Image using only ' + colors[color])
        plt.imshow(image)
    
for i in range(1,6):
    analyze_image_data(i)
# Out:
# Sample image shape: (32, 32, 3)
# Features min 0, max 255
# Sample image shape: (32, 32, 3)
# Features min 0, max 255
# Sample image shape: (32, 32, 3)
# Features min 0, max 255
# Sample image shape: (32, 32, 3)
# Features min 0, max 255
# Sample image shape: (32, 32, 3)
# Features min 0, max 255

# %% [markdown]
# **Answer:** Based on the result above, I would infer that the images are 28x28 pixels and 3-channel RGB (0 to 255 on each channel). It could be any 3 color space, but since RGB is the most common and I can eyeball a slightly difference between tones on the single colored images, I'm guessing it is RGB.

# %% [markdown]
# #### Are the labels in order or random?

# %%
def analyze_label_order(batch_id):
    features, labels = helper.load_cfar10_batch(cifar10_dataset_folder_path, batch_id)
    print("First 20 labels on batch", batch_id, np.array(helper._load_label_names())[[labels[:20]]])
    
for i in range(1,6):
    analyze_label_order(i)
# Out:
# First 20 labels on batch 1 ['frog' 'truck' 'truck' 'deer' 'automobile' 'automobile' 'bird' 'horse'
#  'ship' 'cat' 'deer' 'horse' 'horse' 'bird' 'truck' 'truck' 'truck' 'cat'
#  'bird' 'frog']
# First 20 labels on batch 2 ['automobile' 'frog' 'frog' 'ship' 'ship' 'cat' 'deer' 'frog' 'airplane'
#  'frog' 'airplane' 'cat' 'frog' 'frog' 'dog' 'deer' 'ship' 'cat' 'bird'
#  'frog']
# First 20 labels on batch 3 ['ship' 'dog' 'airplane' 'frog' 'truck' 'bird' 'ship' 'cat' 'frog' 'bird'
#  'horse' 'deer' 'frog' 'truck' 'airplane' 'airplane' 'horse' 'cat' 'horse'
#  'bird']
# First 20 labels on batch 4 ['airplane' 'frog' 'airplane' 'bird' 'horse' 'bird' 'automobile' 'bird'
#  'deer' 'automobile' 'dog' 'frog' 'frog' 'cat' 'automobile' 'cat' 'dog'
#  'dog' 'ship' 'automobile']
# First 20 labels on batch 5 ['automobile' 'ship' 'dog' 'automobile' 'dog' 'horse' 'deer' 'cat' 'ship'
#  'bird' 'horse' 'bird' 'airplane' 'automobile' 'dog' 'truck' 'frog' 'bird'
#  'airplane' 'ship']

# %% [markdown]
# **Answer:** The labels are not ordered.

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    return x / 255


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
from sklearn.preprocessing import LabelBinarizer

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    encoder = LabelBinarizer()
    encoder.fit(range(10))
    return encoder.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf
import numpy as np

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    
    return tf.placeholder(tf.float32, shape=(None,) + image_shape, name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.int32, shape=(None, n_classes), name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    in_shape = x_tensor.shape.as_list()[-1]
    
    # Weights and biases
    conv_weights = tf.Variable(tf.truncated_normal([*conv_ksize, in_shape, conv_num_outputs],
                                        mean=0.0, stddev=1.0 / in_shape, dtype=tf.float32))
    conv_biases = tf.Variable(tf.zeros([conv_num_outputs]))
    
    # Convolution and adding biases
    conv = tf.nn.conv2d(x_tensor, conv_weights, [1, *conv_strides, 1], "SAME")
    pre_activation = tf.nn.bias_add(conv, conv_biases)
    
    # Activation
    activation = tf.nn.relu(pre_activation)
        
    pool = tf.nn.max_pool(activation, [1, *pool_ksize, 1], [1, *pool_strides, 1], "SAME")
    
    return pool


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    s = [-1 if x == None else x for x in x_tensor.get_shape().as_list()]
    return tf.reshape(x_tensor, [s[0], s[1] * s[2] * s[3]])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    in_shape = x_tensor.shape.as_list()[-1]
    
    w = tf.Variable(tf.truncated_normal([in_shape, num_outputs],
                                        mean=0.0, stddev=1.0 / in_shape, dtype=tf.float32))
    b = tf.Variable(tf.zeros([num_outputs]))
    
    pre_activation = tf.matmul(x_tensor, w) + b
      
    return tf.nn.relu(pre_activation)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    in_shape = x_tensor.shape.as_list()[-1]
    
    w = tf.Variable(tf.truncated_normal([in_shape, num_outputs],
                                        mean=0.0, stddev=1.0 / in_shape, dtype=tf.float32))
    b = tf.Variable(tf.zeros([num_outputs]))
    
    return tf.matmul(x_tensor, w) + b


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
NUM_CLASSES=10
def karpathy_conv_net(x, keep_prob):
    # https://cs.stanford.edu/people/karpathy/convnetjs/demo/cifar10.html
    # ~51% accuracy on 1 batch
    # ~57% accuracy on 5 batch
    # ~57% accuracy on test
    
    x = conv2d_maxpool(x, 3, (5, 5), (1, 1), (2, 2), (2, 2))
    x = conv2d_maxpool(x, 16, (5, 5), (1, 1), (2, 2), (2, 2))
    x = conv2d_maxpool(x, 20, (5, 5), (1, 1), (2, 2), (2, 2))
    x = flatten(x)
    x = output(x, 10)
    
    return x

def eric_conv_net(x, keep_prob):
    # https://discussions.udacity.com/t/image-classification-not-working/231425/3
    # ~51% accuracy on 1 batch
    # ~60% accuracy on 5 batch
    # ~58% accuracy on test
    
    x = conv2d_maxpool(x, 96, (3,3), (1,1), (2,2), (2,2))
    x = flatten(x)
    x = fully_conn(x, 512)
    x = output(x, 10)
    
    return x

def gopal_conv_net(x, keep_prob):
    # https://discussions.udacity.com/t/network-does-not-learn-no-2/231391/29
    # ~52% accuracy on 1 batch
    # ~43% accuracy on 5 batch
    # ~42% accuracy on test
    
    x = conv2d_maxpool(x, 16, (4, 4), (1, 1), (2, 2), (2, 2))
    x = conv2d_maxpool(x, 32, (4, 4), (1, 1), (2, 2), (2, 2))
    x = conv2d_maxpool(x, 64, (4, 4), (1, 1), (2, 2), (2, 2))
    x = flatten(x)
    x = fully_conn(x, 10)
    x = tf.nn.dropout(x, keep_prob)
    x = fully_conn(x, 10)
    x = tf.nn.dropout(x, keep_prob)
    x = output(x, 10)
    
    return x

def my_conv_net(x, keep_prob):
    # A mix of karpathy's and gopal's architectures
    # ~53% accuracy on 1 batch
    # ~51% accuracy on 5 batch
    # ~51% accuracy on test
    x = conv2d_maxpool(x, 8, (5, 5), (1, 1), (2, 2), (2, 2))
    x = conv2d_maxpool(x, 16, (5, 5), (1, 1), (2, 2), (2, 2))
    x = conv2d_maxpool(x, 32, (5, 5), (1, 1), (2, 2), (2, 2))
    x = flatten(x)
    x = fully_conn(x, 512)
    x = tf.nn.dropout(x, keep_prob)
    x = output(x, 10)
    
    return x
    

def conv_net(x, keep_prob):
    return my_conv_net(x, keep_prob)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

tf.train.AdadeltaOptimizer()

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    feed_dict = {x : feature_batch, y : label_batch, keep_prob : keep_probability}
    session.run([optimizer], feed_dict=feed_dict)
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    feed_dict = { x: feature_batch, y: label_batch, keep_prob: 1.0 }
    c = session.run([cost], feed_dict=feed_dict)
    feed_dict = { x: valid_features, y: valid_labels, keep_prob: 1.0 }
    a = session.run([accuracy], feed_dict=feed_dict)
    print("Cost: {:.3f}, Accuracy: {:.3f}%".format(c[0], 100*a[0]))
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
epochs = 50
batch_size = 256
keep_probability = 0.9

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost: 2.224, Accuracy: 26.320%
# Epoch  2, CIFAR-10 Batch 1:  Cost: 2.064, Accuracy: 32.840%
# Epoch  3, CIFAR-10 Batch 1:  Cost: 1.943, Accuracy: 38.760%
# Epoch  4, CIFAR-10 Batch 1:  Cost: 1.798, Accuracy: 41.480%
# Epoch  5, CIFAR-10 Batch 1:  Cost: 1.653, Accuracy: 43.340%
# Epoch  6, CIFAR-10 Batch 1:  Cost: 1.531, Accuracy: 44.780%
# Epoch  7, CIFAR-10 Batch 1:  Cost: 1.417, Accuracy: 44.880%
# Epoch  8, CIFAR-10 Batch 1:  Cost: 1.311, Accuracy: 45.780%
# Epoch  9, CIFAR-10 Batch 1:  Cost: 1.242, Accuracy: 45.760%
# Epoch 10, CIFAR-10 Batch 1:  Cost: 1.105, Accuracy: 48.740%
# Epoch 11, CIFAR-10 Batch 1:  Cost: 1.048, Accuracy: 49.800%
# Epoch 12, CIFAR-10 Batch 1:  Cost: 0.947, Accuracy: 49.100%
# Epoch 13, CIFAR-10 Batch 1:  Cost: 0.857, Accuracy: 48.980%
# Epoch 14, CIFAR-10 Batch 1:  Cost: 0.772, Accuracy: 48.380%
# Epoch 15, CIFAR-10 Batch 1:  Cost: 0.689, Accuracy: 49.080%
# Epoch 16, CIFAR-10 Batch 1:  Cost: 0.610, Accuracy: 50.120%
# Epoch 17, CIFAR-10 Batch 1:  Cost: 0.534, Accuracy: 49.800%
# Epoch 18, CIFAR-10 Batch 1:  Cost: 0.460, Accuracy: 50.560%
# Epoch 19, CIFAR-10 Batch 1:  Cost: 0.430, Accuracy: 51.680%
# Epoch 20, CIFAR-10 Batch 1:  Cost: 0.420, Accuracy: 52.040%
# Epoch 21, CIFAR-10 Batch 1:  Cost: 0.358, Accuracy: 51.120%
# Epoch 22, CIFAR-10 Batch 1:  Cost: 0.317, Accuracy: 51.180%
# Epoch 23, CIFAR-10 Batch 1:  Cost: 0.306, Accuracy: 50.180%
# Epoch 24, CIFAR-10 Batch 1:  Cost: 0.269, Accuracy: 50.000%
# Epoch 25, CIFAR-10 Batch 1:  Cost: 0.220, Accuracy: 51.620%
# Epoch 26, CIFAR-10 Batch 1:  Cost: 0.256, Accuracy: 51.420%
# Epoch 27, CIFAR-10 Batch 1:  Cost: 0.175, Accuracy: 53.420%
# Epoch 28, CIFAR-10 Batch 1:  Cost: 0.172, Accuracy: 51.220%
# Epoch 29, CIFAR-10 Batch 1:  Cost: 0.186, Accuracy: 48.880%
# Epoch 30, CIFAR-10 Batch 1:  Cost: 0.171, Accuracy: 50.180%
# Epoch 31, CIFAR-10 Batch 1:  Cost: 0.157, Accuracy: 50.380%
# Epoch 32, CIFAR-10 Batch 1:  Cost: 0.137, Accuracy: 51.500%
# Epoch 33, CIFAR-10 Batch 1:  Cost: 0.133, Accuracy: 52.140%
# Epoch 34, CIFAR-10 Batch 1:  Cost: 0.125, Accuracy: 50.340%
# Epoch 35, CIFAR-10 Batch 1:  Cost: 0.113, Accuracy: 48.660%
# Epoch 36, CIFAR-10 Batch 1:  Cost: 0.086, Accuracy: 48.840%
# Epoch 37, CIFAR-10 Batch 1:  Cost: 0.060, Accuracy: 50.380%
# Epoch 38, CIFAR-10 Batch 1:  Cost: 0.062, Accuracy: 50.920%
# Epoch 39, CIFAR-10 Batch 1:  Cost: 0.078, Accuracy: 49.500%
# Epoch 40, CIFAR-10 Batch 1:  Cost: 0.080, Accuracy: 50.980%
# Epoch 41, CIFAR-10 Batch 1:  Cost: 0.077, Accuracy: 49.320%
# Epoch 42, CIFAR-10 Batch 1:  Cost: 0.067, Accuracy: 49.900%
# Epoch 43, CIFAR-10 Batch 1:  Cost: 0.040, Accuracy: 51.040%
# Epoch 44, CIFAR-10 Batch 1:  Cost: 0.040, Accuracy: 51.400%
# Epoch 45, CIFAR-10 Batch 1:  Cost: 0.035, Accuracy: 51.460%
# Epoch 46, CIFAR-10 Batch 1:  Cost: 0.029, Accuracy: 52.380%
# Epoch 47, CIFAR-10 Batch 1:  Cost: 0.044, Accuracy: 51.520%
# Epoch 48, CIFAR-10 Batch 1:  Cost: 0.030, Accuracy: 52.020%
# Epoch 49, CIFAR-10 Batch 1:  Cost: 0.034, Accuracy: 51.560%
# Epoch 50, CIFAR-10 Batch 1:  Cost: 0.020, Accuracy: 52.700%

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost: 2.187, Accuracy: 25.700%
# Epoch  1, CIFAR-10 Batch 2:  Cost: 1.933, Accuracy: 32.920%
# Epoch  1, CIFAR-10 Batch 3:  Cost: 1.520, Accuracy: 35.420%
# Epoch  1, CIFAR-10 Batch 4:  Cost: 1.628, Accuracy: 41.200%
# Epoch  1, CIFAR-10 Batch 5:  Cost: 1.684, Accuracy: 43.160%
# Epoch  2, CIFAR-10 Batch 1:  Cost: 1.838, Accuracy: 45.640%
# Epoch  2, CIFAR-10 Batch 2:  Cost: 1.606, Accuracy: 43.200%
# Epoch  2, CIFAR-10 Batch 3:  Cost: 1.213, Accuracy: 43.980%
# Epoch  2, CIFAR-10 Batch 4:  Cost: 1.359, Accuracy: 48.680%
# Epoch  2, CIFAR-10 Batch 5:  Cost: 1.475, Accuracy: 47.720%
# Epoch  3, CIFAR-10 Batch 1:  Cost: 1.598, Accuracy: 50.580%
# Epoch  3, CIFAR-10 Batch 2:  Cost: 1.382, Accuracy: 50.460%
# Epoch  3, CIFAR-10 Batch 3:  Cost: 1.098, Accuracy: 46.920%
# Epoch  3, CIFAR-10 Batch 4:  Cost: 1.154, Accuracy: 52.980%
# Epoch  3, CIFAR-10 Batch 5:  Cost: 1.326, Accuracy: 49.540%
# Epoch  4, CIFAR-10 Batch 1:  Cost: 1.414, Accuracy: 53.880%
# Epoch  4, CIFAR-10 Batch 2:  Cost: 1.150, Accuracy: 53.820%
# Epoch  4, CIFAR-10 Batch 3:  Cost: 0.969, Accuracy: 50.960%
# Epoch  4, CIFAR-10 Batch 4:  Cost: 1.030, Accuracy: 54.840%
# Epoch  4, CIFAR-10 Batch 5:  Cost: 1.140, Accuracy: 54.800%
# Epoch  5, CIFAR-10 Batch 1:  Cost: 1.221, Accuracy: 56.020%
# Epoch  5, CIFAR-10 Batch 2:  Cost: 0.971, Accuracy: 56.820%
# Epoch  5, CIFAR-10 Batch 3:  Cost: 0.811, Accuracy: 53.900%
# Epoch  5, CIFAR-10 Batch 4:  Cost: 0.918, Accuracy: 56.980%
# Epoch  5, CIFAR-10 Batch 5:  Cost: 1.002, Accuracy: 57.740%
# Epoch  6, CIFAR-10 Batch 1:  Cost: 1.032, Accuracy: 57.640%
# Epoch  6, CIFAR-10 Batch 2:  Cost: 0.815, Accuracy: 58.860%
# Epoch  6, CIFAR-10 Batch 3:  Cost: 0.690, Accuracy: 56.520%
# Epoch  6, CIFAR-10 Batch 4:  Cost: 0.820, Accuracy: 58.800%
# Epoch  6, CIFAR-10 Batch 5:  Cost: 0.853, Accuracy: 58.100%
# Epoch  7, CIFAR-10 Batch 1:  Cost: 0.864, Accuracy: 59.040%
# Epoch  7, CIFAR-10 Batch 2:  Cost: 0.708, Accuracy: 58.760%
# Epoch  7, CIFAR-10 Batch 3:  Cost: 0.581, Accuracy: 57.240%
# Epoch  7, CIFAR-10 Batch 4:  Cost: 0.722, Accuracy: 60.420%
# Epoch  7, CIFAR-10 Batch 5:  Cost: 0.736, Accuracy: 59.900%
# Epoch  8, CIFAR-10 Batch 1:  Cost: 0.745, Accuracy: 60.640%
# Epoch  8, CIFAR-10 Batch 2:  Cost: 0.597, Accuracy: 59.620%
# Epoch  8, CIFAR-10 Batch 3:  Cost: 0.493, Accuracy: 59.020%
# Epoch  8, CIFAR-10 Batch 4:  Cost: 0.660, Accuracy: 61.500%
# Epoch  8, CIFAR-10 Batch 5:  Cost: 0.606, Accuracy: 60.620%
# Epoch  9, CIFAR-10 Batch 1:  Cost: 0.627, Accuracy: 61.200%
# Epoch  9, CIFAR-10 Batch 2:  Cost: 0.482, Accuracy: 60.420%
# Epoch  9, CIFAR-10 Batch 3:  Cost: 0.422, Accuracy: 61.040%
# Epoch  9, CIFAR-10 Batch 4:  Cost: 0.596, Accuracy: 62.120%
# Epoch  9, CIFAR-10 Batch 5:  Cost: 0.499, Accuracy: 61.000%
# Epoch 10, CIFAR-10 Batch 1:  Cost: 0.571, Accuracy: 60.620%
# Epoch 10, CIFAR-10 Batch 2:  Cost: 0.380, Accuracy: 61.240%
# Epoch 10, CIFAR-10 Batch 3:  Cost: 0.344, Accuracy: 62.540%
# Epoch 10, CIFAR-10 Batch 4:  Cost: 0.505, Accuracy: 62.500%
# Epoch 10, CIFAR-10 Batch 5:  Cost: 0.406, Accuracy: 61.400%
# Epoch 11, CIFAR-10 Batch 1:  Cost: 0.465, Accuracy: 61.320%
# Epoch 11, CIFAR-10 Batch 2:  Cost: 0.337, Accuracy: 61.300%
# Epoch 11, CIFAR-10 Batch 3:  Cost: 0.291, Accuracy: 63.160%
# Epoch 11, CIFAR-10 Batch 4:  Cost: 0.444, Accuracy: 62.680%
# Epoch 11, CIFAR-10 Batch 5:  Cost: 0.362, Accuracy: 62.960%
# Epoch 12, CIFAR-10 Batch 1:  Cost: 0.406, Accuracy: 61.140%
# Epoch 12, CIFAR-10 Batch 2:  Cost: 0.282, Accuracy: 61.720%
# Epoch 12, CIFAR-10 Batch 3:  Cost: 0.251, Accuracy: 63.240%
# Epoch 12, CIFAR-10 Batch 4:  Cost: 0.405, Accuracy: 62.680%
# Epoch 12, CIFAR-10 Batch 5:  Cost: 0.290, Accuracy: 63.800%
# Epoch 13, CIFAR-10 Batch 1:  Cost: 0.346, Accuracy: 62.420%
# Epoch 13, CIFAR-10 Batch 2:  Cost: 0.242, Accuracy: 62.660%
# Epoch 13, CIFAR-10 Batch 3:  Cost: 0.210, Accuracy: 63.180%
# Epoch 13, CIFAR-10 Batch 4:  Cost: 0.353, Accuracy: 62.380%
# Epoch 13, CIFAR-10 Batch 5:  Cost: 0.290, Accuracy: 63.560%
# Epoch 14, CIFAR-10 Batch 1:  Cost: 0.292, Accuracy: 63.560%
# Epoch 14, CIFAR-10 Batch 2:  Cost: 0.220, Accuracy: 63.160%
# Epoch 14, CIFAR-10 Batch 3:  Cost: 0.206, Accuracy: 61.860%
# Epoch 14, CIFAR-10 Batch 4:  Cost: 0.283, Accuracy: 63.320%
# Epoch 14, CIFAR-10 Batch 5:  Cost: 0.262, Accuracy: 63.440%
# Epoch 15, CIFAR-10 Batch 1:  Cost: 0.261, Accuracy: 64.300%
# Epoch 15, CIFAR-10 Batch 2:  Cost: 0.189, Accuracy: 62.960%
# Epoch 15, CIFAR-10 Batch 3:  Cost: 0.180, Accuracy: 62.280%
# Epoch 15, CIFAR-10 Batch 4:  Cost: 0.238, Accuracy: 62.900%
# Epoch 15, CIFAR-10 Batch 5:  Cost: 0.198, Accuracy: 63.960%
# Epoch 16, CIFAR-10 Batch 1:  Cost: 0.225, Accuracy: 64.160%
# Epoch 16, CIFAR-10 Batch 2:  Cost: 0.152, Accuracy: 62.960%
# Epoch 16, CIFAR-10 Batch 3:  Cost: 0.164, Accuracy: 62.360%
# Epoch 16, CIFAR-10 Batch 4:  Cost: 0.216, Accuracy: 63.980%
# Epoch 16, CIFAR-10 Batch 5:  Cost: 0.184, Accuracy: 63.220%
# Epoch 17, CIFAR-10 Batch 1:  Cost: 0.186, Accuracy: 64.060%
# Epoch 17, CIFAR-10 Batch 2:  Cost: 0.129, Accuracy: 63.800%
# Epoch 17, CIFAR-10 Batch 3:  Cost: 0.146, Accuracy: 62.380%
# Epoch 17, CIFAR-10 Batch 4:  Cost: 0.194, Accuracy: 64.440%
# Epoch 17, CIFAR-10 Batch 5:  Cost: 0.149, Accuracy: 63.860%
# Epoch 18, CIFAR-10 Batch 1:  Cost: 0.147, Accuracy: 64.980%
# Epoch 18, CIFAR-10 Batch 2:  Cost: 0.111, Accuracy: 64.360%
# Epoch 18, CIFAR-10 Batch 3:  Cost: 0.131, Accuracy: 63.360%
# Epoch 18, CIFAR-10 Batch 4:  Cost: 0.180, Accuracy: 63.760%
# Epoch 18, CIFAR-10 Batch 5:  Cost: 0.143, Accuracy: 63.440%
# Epoch 19, CIFAR-10 Batch 1:  Cost: 0.150, Accuracy: 64.280%
# Epoch 19, CIFAR-10 Batch 2:  Cost: 0.094, Accuracy: 64.600%
# Epoch 19, CIFAR-10 Batch 3:  Cost: 0.112, Accuracy: 62.680%
# Epoch 19, CIFAR-10 Batch 4:  Cost: 0.192, Accuracy: 63.040%
# Epoch 19, CIFAR-10 Batch 5:  Cost: 0.120, Accuracy: 62.500%
# Epoch 20, CIFAR-10 Batch 1:  Cost: 0.127, Accuracy: 64.680%
# Epoch 20, CIFAR-10 Batch 2:  Cost: 0.090, Accuracy: 64.400%
# Epoch 20, CIFAR-10 Batch 3:  Cost: 0.107, Accuracy: 63.680%
# Epoch 20, CIFAR-10 Batch 4:  Cost: 0.184, Accuracy: 63.200%
# Epoch 20, CIFAR-10 Batch 5:  Cost: 0.086, Accuracy: 64.000%
# Epoch 21, CIFAR-10 Batch 1:  Cost: 0.139, Accuracy: 62.620%
# Epoch 21, CIFAR-10 Batch 2:  Cost: 0.092, Accuracy: 63.660%
# Epoch 21, CIFAR-10 Batch 3:  Cost: 0.103, Accuracy: 61.940%
# Epoch 21, CIFAR-10 Batch 4:  Cost: 0.157, Accuracy: 63.720%
# Epoch 21, CIFAR-10 Batch 5:  Cost: 0.085, Accuracy: 64.020%
# Epoch 22, CIFAR-10 Batch 1:  Cost: 0.120, Accuracy: 62.760%
# Epoch 22, CIFAR-10 Batch 2:  Cost: 0.088, Accuracy: 63.480%
# Epoch 22, CIFAR-10 Batch 3:  Cost: 0.104, Accuracy: 62.040%
# Epoch 22, CIFAR-10 Batch 4:  Cost: 0.128, Accuracy: 63.300%
# Epoch 22, CIFAR-10 Batch 5:  Cost: 0.067, Accuracy: 64.320%
# Epoch 23, CIFAR-10 Batch 1:  Cost: 0.108, Accuracy: 62.680%
# Epoch 23, CIFAR-10 Batch 2:  Cost: 0.084, Accuracy: 63.100%
# Epoch 23, CIFAR-10 Batch 3:  Cost: 0.075, Accuracy: 62.760%
# Epoch 23, CIFAR-10 Batch 4:  Cost: 0.096, Accuracy: 63.340%
# Epoch 23, CIFAR-10 Batch 5:  Cost: 0.059, Accuracy: 65.200%
# Epoch 24, CIFAR-10 Batch 1:  Cost: 0.108, Accuracy: 62.040%
# Epoch 24, CIFAR-10 Batch 2:  Cost: 0.083, Accuracy: 63.560%
# Epoch 24, CIFAR-10 Batch 3:  Cost: 0.061, Accuracy: 63.760%
# Epoch 24, CIFAR-10 Batch 4:  Cost: 0.097, Accuracy: 63.640%
# Epoch 24, CIFAR-10 Batch 5:  Cost: 0.075, Accuracy: 63.660%
# Epoch 25, CIFAR-10 Batch 1:  Cost: 0.118, Accuracy: 61.140%
# Epoch 25, CIFAR-10 Batch 2:  Cost: 0.106, Accuracy: 63.120%
# Epoch 25, CIFAR-10 Batch 3:  Cost: 0.057, Accuracy: 64.400%
# Epoch 25, CIFAR-10 Batch 4:  Cost: 0.090, Accuracy: 63.140%
# Epoch 25, CIFAR-10 Batch 5:  Cost: 0.067, Accuracy: 61.880%
# Epoch 26, CIFAR-10 Batch 1:  Cost: 0.073, Accuracy: 61.440%
# Epoch 26, CIFAR-10 Batch 2:  Cost: 0.088, Accuracy: 62.580%
# Epoch 26, CIFAR-10 Batch 3:  Cost: 0.044, Accuracy: 64.240%
# Epoch 26, CIFAR-10 Batch 4:  Cost: 0.093, Accuracy: 61.840%
# Epoch 26, CIFAR-10 Batch 5:  Cost: 0.052, Accuracy: 63.540%
# Epoch 27, CIFAR-10 Batch 1:  Cost: 0.062, Accuracy: 63.080%
# Epoch 27, CIFAR-10 Batch 2:  Cost: 0.098, Accuracy: 61.580%
# Epoch 27, CIFAR-10 Batch 3:  Cost: 0.057, Accuracy: 63.880%
# Epoch 27, CIFAR-10 Batch 4:  Cost: 0.078, Accuracy: 61.960%
# Epoch 27, CIFAR-10 Batch 5:  Cost: 0.043, Accuracy: 64.260%
# Epoch 28, CIFAR-10 Batch 1:  Cost: 0.045, Accuracy: 63.920%
# Epoch 28, CIFAR-10 Batch 2:  Cost: 0.061, Accuracy: 62.040%
# Epoch 28, CIFAR-10 Batch 3:  Cost: 0.047, Accuracy: 63.460%
# Epoch 28, CIFAR-10 Batch 4:  Cost: 0.060, Accuracy: 62.560%
# Epoch 28, CIFAR-10 Batch 5:  Cost: 0.041, Accuracy: 65.300%
# Epoch 29, CIFAR-10 Batch 1:  Cost: 0.042, Accuracy: 64.320%
# Epoch 29, CIFAR-10 Batch 2:  Cost: 0.066, Accuracy: 62.520%
# Epoch 29, CIFAR-10 Batch 3:  Cost: 0.042, Accuracy: 63.520%
# Epoch 29, CIFAR-10 Batch 4:  Cost: 0.065, Accuracy: 62.100%
# Epoch 29, CIFAR-10 Batch 5:  Cost: 0.042, Accuracy: 64.460%
# Epoch 30, CIFAR-10 Batch 1:  Cost: 0.048, Accuracy: 63.780%
# Epoch 30, CIFAR-10 Batch 2:  Cost: 0.067, Accuracy: 61.280%
# Epoch 30, CIFAR-10 Batch 3:  Cost: 0.063, Accuracy: 63.080%
# Epoch 30, CIFAR-10 Batch 4:  Cost: 0.071, Accuracy: 62.160%
# Epoch 30, CIFAR-10 Batch 5:  Cost: 0.047, Accuracy: 63.760%
# Epoch 31, CIFAR-10 Batch 1:  Cost: 0.043, Accuracy: 64.080%
# Epoch 31, CIFAR-10 Batch 2:  Cost: 0.055, Accuracy: 62.580%
# Epoch 31, CIFAR-10 Batch 3:  Cost: 0.040, Accuracy: 63.620%
# Epoch 31, CIFAR-10 Batch 4:  Cost: 0.082, Accuracy: 63.600%
# Epoch 31, CIFAR-10 Batch 5:  Cost: 0.035, Accuracy: 65.220%
# Epoch 32, CIFAR-10 Batch 1:  Cost: 0.032, Accuracy: 64.900%
# Epoch 32, CIFAR-10 Batch 2:  Cost: 0.034, Accuracy: 63.540%
# Epoch 32, CIFAR-10 Batch 3:  Cost: 0.041, Accuracy: 63.340%
# Epoch 32, CIFAR-10 Batch 4:  Cost: 0.051, Accuracy: 63.920%
# Epoch 32, CIFAR-10 Batch 5:  Cost: 0.032, Accuracy: 63.340%
# Epoch 33, CIFAR-10 Batch 1:  Cost: 0.026, Accuracy: 64.980%
# Epoch 33, CIFAR-10 Batch 2:  Cost: 0.048, Accuracy: 62.500%
# Epoch 33, CIFAR-10 Batch 3:  Cost: 0.027, Accuracy: 63.040%
# Epoch 33, CIFAR-10 Batch 4:  Cost: 0.049, Accuracy: 63.580%
# Epoch 33, CIFAR-10 Batch 5:  Cost: 0.035, Accuracy: 63.200%
# Epoch 34, CIFAR-10 Batch 1:  Cost: 0.042, Accuracy: 64.180%
# Epoch 34, CIFAR-10 Batch 2:  Cost: 0.057, Accuracy: 61.260%
# Epoch 34, CIFAR-10 Batch 3:  Cost: 0.026, Accuracy: 62.020%
# Epoch 34, CIFAR-10 Batch 4:  Cost: 0.047, Accuracy: 62.400%
# Epoch 34, CIFAR-10 Batch 5:  Cost: 0.033, Accuracy: 63.120%
# Epoch 35, CIFAR-10 Batch 1:  Cost: 0.054, Accuracy: 62.660%
# Epoch 35, CIFAR-10 Batch 2:  Cost: 0.050, Accuracy: 59.640%
# Epoch 35, CIFAR-10 Batch 3:  Cost: 0.044, Accuracy: 62.600%
# Epoch 35, CIFAR-10 Batch 4:  Cost: 0.045, Accuracy: 62.580%
# Epoch 35, CIFAR-10 Batch 5:  Cost: 0.035, Accuracy: 63.520%
# Epoch 36, CIFAR-10 Batch 1:  Cost: 0.042, Accuracy: 61.880%
# Epoch 36, CIFAR-10 Batch 2:  Cost: 0.053, Accuracy: 61.040%
# Epoch 36, CIFAR-10 Batch 3:  Cost: 0.045, Accuracy: 62.880%
# Epoch 36, CIFAR-10 Batch 4:  Cost: 0.040, Accuracy: 61.180%
# Epoch 36, CIFAR-10 Batch 5:  Cost: 0.040, Accuracy: 62.420%
# Epoch 37, CIFAR-10 Batch 1:  Cost: 0.031, Accuracy: 62.900%
# Epoch 37, CIFAR-10 Batch 2:  Cost: 0.021, Accuracy: 62.300%
# Epoch 37, CIFAR-10 Batch 3:  Cost: 0.043, Accuracy: 62.320%
# Epoch 37, CIFAR-10 Batch 4:  Cost: 0.038, Accuracy: 61.760%
# Epoch 37, CIFAR-10 Batch 5:  Cost: 0.035, Accuracy: 62.080%
# Epoch 38, CIFAR-10 Batch 1:  Cost: 0.020, Accuracy: 62.980%
# Epoch 38, CIFAR-10 Batch 2:  Cost: 0.017, Accuracy: 62.440%
# Epoch 38, CIFAR-10 Batch 3:  Cost: 0.026, Accuracy: 62.720%
# Epoch 38, CIFAR-10 Batch 4:  Cost: 0.052, Accuracy: 60.100%
# Epoch 38, CIFAR-10 Batch 5:  Cost: 0.042, Accuracy: 62.840%
# Epoch 39, CIFAR-10 Batch 1:  Cost: 0.018, Accuracy: 63.840%
# Epoch 39, CIFAR-10 Batch 2:  Cost: 0.020, Accuracy: 62.860%
# Epoch 39, CIFAR-10 Batch 3:  Cost: 0.011, Accuracy: 62.220%
# Epoch 39, CIFAR-10 Batch 4:  Cost: 0.026, Accuracy: 60.680%
# Epoch 39, CIFAR-10 Batch 5:  Cost: 0.045, Accuracy: 62.080%
# Epoch 40, CIFAR-10 Batch 1:  Cost: 0.019, Accuracy: 62.420%
# Epoch 40, CIFAR-10 Batch 2:  Cost: 0.016, Accuracy: 61.940%
# Epoch 40, CIFAR-10 Batch 3:  Cost: 0.014, Accuracy: 62.180%
# Epoch 40, CIFAR-10 Batch 4:  Cost: 0.030, Accuracy: 61.940%
# Epoch 40, CIFAR-10 Batch 5:  Cost: 0.028, Accuracy: 62.800%
# Epoch 41, CIFAR-10 Batch 1:  Cost: 0.024, Accuracy: 62.440%
# Epoch 41, CIFAR-10 Batch 2:  Cost: 0.010, Accuracy: 62.980%
# Epoch 41, CIFAR-10 Batch 3:  Cost: 0.015, Accuracy: 62.680%
# Epoch 41, CIFAR-10 Batch 4:  Cost: 0.019, Accuracy: 61.100%
# Epoch 41, CIFAR-10 Batch 5:  Cost: 0.029, Accuracy: 62.380%
# Epoch 42, CIFAR-10 Batch 1:  Cost: 0.017, Accuracy: 61.780%
# Epoch 42, CIFAR-10 Batch 2:  Cost: 0.013, Accuracy: 63.340%
# Epoch 42, CIFAR-10 Batch 3:  Cost: 0.012, Accuracy: 61.660%
# Epoch 42, CIFAR-10 Batch 4:  Cost: 0.031, Accuracy: 60.460%
# Epoch 42, CIFAR-10 Batch 5:  Cost: 0.026, Accuracy: 61.740%
# Epoch 43, CIFAR-10 Batch 1:  Cost: 0.014, Accuracy: 61.400%
# Epoch 43, CIFAR-10 Batch 2:  Cost: 0.012, Accuracy: 62.440%
# Epoch 43, CIFAR-10 Batch 3:  Cost: 0.011, Accuracy: 61.440%
# Epoch 43, CIFAR-10 Batch 4:  Cost: 0.025, Accuracy: 60.940%
# Epoch 43, CIFAR-10 Batch 5:  Cost: 0.033, Accuracy: 61.840%
# Epoch 44, CIFAR-10 Batch 1:  Cost: 0.020, Accuracy: 60.440%
# Epoch 44, CIFAR-10 Batch 2:  Cost: 0.012, Accuracy: 62.580%
# Epoch 44, CIFAR-10 Batch 3:  Cost: 0.005, Accuracy: 62.420%
# Epoch 44, CIFAR-10 Batch 4:  Cost: 0.021, Accuracy: 61.320%
# Epoch 44, CIFAR-10 Batch 5:  Cost: 0.020, Accuracy: 62.020%
# Epoch 45, CIFAR-10 Batch 1:  Cost: 0.018, Accuracy: 61.480%
# Epoch 45, CIFAR-10 Batch 2:  Cost: 0.014, Accuracy: 62.040%
# Epoch 45, CIFAR-10 Batch 3:  Cost: 0.009, Accuracy: 61.320%
# Epoch 45, CIFAR-10 Batch 4:  Cost: 0.015, Accuracy: 62.360%
# Epoch 45, CIFAR-10 Batch 5:  Cost: 0.013, Accuracy: 62.100%
# Epoch 46, CIFAR-10 Batch 1:  Cost: 0.022, Accuracy: 60.760%
# Epoch 46, CIFAR-10 Batch 2:  Cost: 0.011, Accuracy: 61.700%
# Epoch 46, CIFAR-10 Batch 3:  Cost: 0.007, Accuracy: 60.820%
# Epoch 46, CIFAR-10 Batch 4:  Cost: 0.014, Accuracy: 62.660%
# Epoch 46, CIFAR-10 Batch 5:  Cost: 0.017, Accuracy: 62.420%
# Epoch 47, CIFAR-10 Batch 1:  Cost: 0.025, Accuracy: 61.500%
# Epoch 47, CIFAR-10 Batch 2:  Cost: 0.011, Accuracy: 61.820%
# Epoch 47, CIFAR-10 Batch 3:  Cost: 0.009, Accuracy: 61.420%
# Epoch 47, CIFAR-10 Batch 4:  Cost: 0.023, Accuracy: 62.020%
# Epoch 47, CIFAR-10 Batch 5:  Cost: 0.023, Accuracy: 60.680%
# Epoch 48, CIFAR-10 Batch 1:  Cost: 0.022, Accuracy: 60.780%
# Epoch 48, CIFAR-10 Batch 2:  Cost: 0.010, Accuracy: 61.160%
# Epoch 48, CIFAR-10 Batch 3:  Cost: 0.006, Accuracy: 61.860%
# Epoch 48, CIFAR-10 Batch 4:  Cost: 0.012, Accuracy: 63.360%
# Epoch 48, CIFAR-10 Batch 5:  Cost: 0.018, Accuracy: 60.920%
# Epoch 49, CIFAR-10 Batch 1:  Cost: 0.016, Accuracy: 60.300%
# Epoch 49, CIFAR-10 Batch 2:  Cost: 0.013, Accuracy: 60.980%
# Epoch 49, CIFAR-10 Batch 3:  Cost: 0.011, Accuracy: 62.280%
# Epoch 49, CIFAR-10 Batch 4:  Cost: 0.009, Accuracy: 63.820%
# Epoch 49, CIFAR-10 Batch 5:  Cost: 0.015, Accuracy: 60.840%
# Epoch 50, CIFAR-10 Batch 1:  Cost: 0.023, Accuracy: 60.200%
# Epoch 50, CIFAR-10 Batch 2:  Cost: 0.009, Accuracy: 60.500%
# Epoch 50, CIFAR-10 Batch 3:  Cost: 0.011, Accuracy: 62.660%
# Epoch 50, CIFAR-10 Batch 4:  Cost: 0.013, Accuracy: 63.020%
# Epoch 50, CIFAR-10 Batch 5:  Cost: 0.014, Accuracy: 61.920%

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.61728515625

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
